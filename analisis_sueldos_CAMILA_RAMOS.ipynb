# %% [markdown]
# # Análisis de sueldos con Python

# %% [markdown]
# ## Data
#
# * [2021.2 - sysarmy - Encuesta de remuneración salarial Argentina
# ](https://docs.google.com/spreadsheets/d/1-ZRznwS4TK74o90aOiCKS5SiXxUQ2buN1wxZIMHQmzQ/edit#gid=557755710)
# * [2021.2 - sysarmy - Encuesta de remuneración salarial Latam
# ](https://docs.google.com/spreadsheets/d/1BkBNt1MHVS7DeIlpgmK9l6krtSQ5t_olRhlcyxMeKy0/edit#gid=557755710)

# %% [markdown]
# 1. Descargar, leer y unir en una sola estructura de datos. ¿Qué estructura elegiste y por qué?

# %%
# 2021.2 - sysarmy - Encuesta de remuneración salarial Argentina - Argentina.csv
# 2021.2 - sysarmy - Encuesta de remuneración salarial Latam - Latam.csv

import csv #libreria para leer csv

path_to_file_1 = '2021.2 - sysarmy - Encuesta de remuneración salarial Argentina - Argentina.csv'
path_to_file_2 = '2021.2 - sysarmy - Encuesta de remuneración salarial Latam - Latam.csv'

raw_cases_list_ARG = []
raw_cases_list_LATAM = []


with open(f"{path_to_file_1}", "r") as f1:
    reader = csv.reader(f1)
    for linea in reader:
        raw_cases_list_ARG.append(linea)

with open(f"{path_to_file_2}", "r") as f2:
    reader = csv.reader(f2)
    for linea in reader:
        raw_cases_list_LATAM.append(linea)

# %%
#chequeo posicion de cada pregunta para poder utilizarla como key de mi diccionario
for i,c in enumerate(raw_cases_list_ARG[9]):
    print (i,c)
# Out:
# 0 Dónde estás trabajando
# 1 Tipo de contrato
# 2 Salario mensual o retiro BRUTO (en tu moneda local)
# 3 Salario mensual o retiro NETO (en tu moneda local)
# 4 Pagos en dólares
# 5 ¿Cuál fue el último valor de dólar que tomaron?
# 6 ¿Qué tan conforme estás con tu sueldo?
# 7 Cómo creés que está tu sueldo con respecto al último semestre
# 8 Recibís algún tipo de bono
# 9 A qué está atado el bono
# 10 ¿Tuviste ajustes por inflación durante 2021?
# 11 ¿De qué % fue el ajuste total?
# 12 ¿En qué mes fue el último ajuste?
# 13 Trabajo de
# 14 Años de experiencia
# 15 Años en la empresa actual
# 16 Años en el puesto actual
# 17 ¿Gente a cargo?
# 18 Plataformas
# 19 Lenguajes de programación o tecnologías.
# 20 Frameworks, herramientas y librerías
# 21 Bases de datos
# 22 QA / Testing
# 23 IDEs
# 24 Cantidad de personas en tu organización
# 25 Trabajo para una empresa que no tiene oficina en mi ciudad
# 26 Actividad principal
# 27 ¿La recomendás como un buen lugar para trabajar?
# 28 ¿Cómo calificás las políticas de diversidad e inclusión?
# 29 Beneficios extra
# 30 ¿Salir o seguir contestando?
# 31 Nivel de estudios alcanzado
# 32 Estado
# 33 Carrera
# 34 Universidad
# 35 Realizaste cursos de especialización
# 36 ¿Contribuís a proyectos open source?
# 37 ¿Programás como hobbie?
# 38 ¿Salir o seguir contestando?
# 39 ¿Tenés guardias?
# 40 Cuánto cobrás por guardia
# 41 ¿Porcentaje, bruto o neto?
# 42 ¿Salir o seguir contestando?
# 43 ¿Sufriste o presenciaste situaciones de violencia laboral?
# 44 ¿Tenés algún tipo de discapacidad?
# 45 ¿Sentís que esto te dificultó el conseguir trabajo?
# 46 ¿Salir o seguir contestando?
# 47 ¿Cómo venís llevando la pandemia?
# 48 ¿Tenés hijos/as menores de edad?
# 49 ¿Con cuántas personas estás conviviendo?
# 50 ¿Con quiénes convivís?
# 51 ¿Tenés un espacio dedicado para el trabajo?
# 52 ¿Tenés que compartir tu equipo de trabajo con alguien?
# 53 ¿Qué tipo de cuarentena hiciste / estás haciendo?
# 54 ¿Cambió tu situación laboral a raíz de la pandemia?
# 55 ¿Qué tanto sentís que te está apoyando tu empresa/organización en esta situación?
# 56 ¿Cómo se vio afectada tu empresa/organización?
# 57 ¿Instauraron algún beneficio nuevo?
# 58 Tengo
# 59 Me identifico

# %%
#borro filas sin respuestas
del raw_cases_list_ARG[:10]

# %%
# armo lista de diccionaros con respuestas que voy a utilizar de ARG
dict_cases_list_ARG =[]

for case in raw_cases_list_ARG:
       dict_cases_list_ARG.append({ 
           "Pais": "Argentina",
           "Region": case[0],
           "Tipo contrato": case[1],
           "Salario bruto": case[2],
           "Salario neto": case[3],
           "Sueldo dolarizado": case[4],
           "Valor de dolar tomado":case[5],
           "Tipo de rol":case[13].lower(),
           "Años de experiencia": case[14],
           "Antiguedad en la empresa actual": case[15],
           "Antiguedad en el puesto actual": case[16],
           "Lenguajes de programacion": case[19],
           "Nivel de educacion":case[31],
           "Estado del nivel" :case[32],
           "Carrera Universitaria": case[33],
           "Cursos de especializacion": case[35],
           "Colabora en Open Source": case [36],
           "Programa por hobbie": case[44],
           "Persona con discapacidad":case [58],
           "Edad": case[58],
           "Identidad de genero": case[59]
            })

print(len(dict_cases_list_ARG))
# Out:
# 6450

# %%
print(dict_cases_list_ARG[0:2])
# Out:
# [{'Pais': 'Argentina', 'Region': 'Catamarca', 'Tipo contrato': 'Full-Time', 'Salario bruto': '245000', 'Salario neto': '169000', 'Sueldo dolarizado': '', 'Valor de dolar tomado': '', 'Tipo de rol': 'Developer', 'Años de experiencia': '3', 'Antiguedad en la empresa actual': '0', 'Antiguedad en el puesto actual': '3', 'Lenguajes de programacion': 'CSS, HTML, Javascript, TypeScript', 'Nivel de educacion': '', 'Estado del nivel': '', 'Carrera Universitaria': '', 'Cursos de especializacion': '', 'Colabora en Open Source': '', 'Programa por hobbie': '', 'Persona con discapacidad': '28', 'Edad': '28', 'Identidad de genero': 'Varón Cis'}, {'Pais': 'Argentina', 'Region': 'Catamarca', 'Tipo contrato': 'Tercerizado (trabajo a través de consultora o agencia)', 'Salario bruto': '180000', 'Salario neto': '126000', 'Sueldo dolarizado': '', 'Valor de dolar tomado': '', 'Tipo de rol': 'Technical Leader', 'Años de experiencia': '9', 'Antiguedad en la empresa actual': '0', 'Antiguedad en el puesto actual': '0', 'Lenguajes de programacion': 'Python', 'Nivel de educacion': 'Universitario', 'Estado del nivel': 'Completado', 'Carrera Universitaria': 'Lic. En redes y comunicación de datos ', 'Cursos de especializacion': 'Sí, de forma particular, Sí, los pagó un empleador', 'Colabora en Open Source': 'Sí', 'Programa por hobbie': '', 'Persona con discapacidad': '34', 'Edad': '34', 'Identidad de genero': 'Varón Cis'}]

# %%
#chequeo posicion de cada pregunta para poder utilizarla como key de mi diccionario
for i,c in enumerate(raw_cases_list_LATAM[10]):
    print (i,c)
# Out:
# 0 Estoy trabajando en
# 1 Bolivia
# 2 Chile
# 3 Colombia
# 4 Costa Rica
# 5 Cuba
# 6 Ecuador
# 7 El Salvador
# 8 Guatemala
# 9 Honduras
# 10 México
# 11 Nicaragua
# 12 Panamá
# 13 Paraguay
# 14 Perú
# 15 Puerto Rico
# 16 República Dominicana
# 17 Uruguay
# 18 Venezuela
# 19 Tipo de contrato
# 20 Salario mensual o retiro BRUTO (en tu moneda local)
# 21 Salario mensual o retiro NETO (en tu moneda local)
# 22 Pagos en dólares
# 23 ¿Cuál fue el último valor de dólar que tomaron?
# 24 ¿Qué tan conforme estás con tu sueldo?
# 25 Cómo creés que está tu sueldo con respecto al último semestre
# 26 Recibís algún tipo de bono
# 27 A qué está atado el bono
# 28 ¿Tuviste ajustes por inflación durante 2021?
# 29 ¿De qué % fue el ajuste total?
# 30 ¿En qué mes fue el último ajuste?
# 31 Trabajo de
# 32 Años de experiencia
# 33 Años en la empresa actual
# 34 Años en el puesto actual
# 35 ¿Gente a cargo?
# 36 Plataformas
# 37 Lenguajes de programación o tecnologías.
# 38 Frameworks, herramientas y librerías
# 39 Bases de datos
# 40 QA / Testing
# 41 IDEs
# 42 Cantidad de personas en tu organización
# 43
# 44 Actividad principal
# 45 ¿La recomendás como un buen lugar para trabajar?
# 46 ¿Cómo calificás las políticas de diversidad e inclusión?
# 47 Beneficios extra
# 48 ¿Salir o seguir contestando?
# 49 Nivel de estudios alcanzado
# 50 Estado
# 51 Carrera
# 52 Universidad
# 53 Realizaste cursos de especialización
# 54 ¿Contribuís a proyectos open source?
# 55 ¿Programás como hobbie?
# 56 ¿Salir o seguir contestando?
# 57 ¿Tenés guardias?
# 58 Cuánto cobrás por guardia
# 59 ¿Porcentaje, bruto o neto?
# 60 ¿Salir o seguir contestando?
# 61 ¿Sufriste o presenciaste situaciones de violencia laboral?
# 62 ¿Tenés algún tipo de discapacidad?
# 63 ¿Sentís que esto te dificultó el conseguir trabajo?
# 64 ¿Salir o seguir contestando?
# 65 ¿Cómo venís llevando la pandemia?
# 66 ¿Tenés hijos/as menores de edad?
# 67 ¿Con cuántas personas estás conviviendo?
# 68 ¿Con quiénes convivís?
# 69 ¿Tenés un espacio dedicado para el trabajo?
# 70 ¿Tenés que compartir tu equipo de trabajo con alguien?
# 71 ¿Qué tipo de cuarentena hiciste / estás haciendo?
# 72 ¿Cambió tu situación laboral a raíz de la pandemia?
# 73 ¿Qué tanto sentís que te está apoyando tu empresa/organización en esta situación?
# 74 ¿Cómo se vio afectada tu empresa/organización?
# 75 ¿Instauraron algún beneficio nuevo?
# 76 Tengo
# 77 Me identifico

# %%
#borro filas sin respuestas
del raw_cases_list_LATAM[:11]

# %%
# armo lista de diccionaros con respuestas que voy a utilizar de LATAM
dict_cases_list_LATAM =[]

for case in raw_cases_list_LATAM:
    for i in range (1,19): 
        if case[i]:
            region = case[i]
            break
    dict_cases_list_LATAM.append({ 
           "Pais": case[0],
           "Region": region,
           "Tipo contrato": case[19],
           "Salario bruto": case[20],
           "Salario neto": case[21],
           "Sueldo dolarizado": case[22],
           "Valor de dolar tomado":case[23],
           "Tipo de rol":case[31].lower(),
           "Años de experiencia": case[32],
           "Antiguedad en la empresa actual": case[33],
           "Antiguedad en el puesto actual": case[34],
           "Lenguajes de programacion": case[37],
           "Nivel de educacion":case[49],
           "Estado del nivel" :case[50],
           "Carrera Universitaria": case[51],
           "Cursos de especializacion": case[53],
           "Colabora en Open Source": case [54],
           "Programa por hobbie": case[55],
           "Persona con discapacidad":case [62],
           "Edad": case[76],
           "Identidad de genero": case[77]
            })

print(len(dict_cases_list_LATAM))
# Out:
# 429

# %%
dict_cases_list_LATAM[0:2]
# Out:
# [{'Pais': 'Bolivia',
#   'Region': 'Cochabamba',
#   'Tipo contrato': 'Full-Time',
#   'Salario bruto': '13500',
#   'Salario neto': '12000',
#   'Sueldo dolarizado': '',
#   'Valor de dolar tomado': '',
#   'Tipo de rol': 'sysadmin / devops / sre',
#   'Años de experiencia': '6',
#   'Antiguedad en la empresa actual': '14',
#   'Antiguedad en el puesto actual': '6',
#   'Lenguajes de programacion': 'Bash/Shell',
#   'Nivel de educacion': 'Terciario',
#   'Estado del nivel': 'Completado',
#   'Carrera Universitaria': 'Analista de Sistemas',
#   'Cursos de especializacion': 'Sí, los pagó un empleador',
#   'Colabora en Open Source': 'No',
#   'Programa por hobbie': 'No',
#   'Persona con discapacidad': '',
#   'Edad': '35',
#   'Identidad de genero': 'Varón Cis'},
#  {'Pais': 'Bolivia',
#   'Region': 'La Paz',
#   'Tipo contrato': 'Remoto (empresa de otro país)',
#   'Salario bruto': '24000',
#   'Salario neto': '21000',
#   'Sueldo dolarizado': 'Cobro en dólares',
#   'Valor de dolar tomado': '',
#   'Tipo de rol': 'developer',
#   'Años de experiencia': '12',
#   'Antiguedad en la empresa actual': '1',
#   'Antiguedad en el puesto actual': '6',
#   'Lenguajes de programacion': 'Bash/Shell, Ruby',
#   'Nivel de educacion': '',
#   'Estado del nivel': '',
#   'Carrera Universitaria': '',
#   'Cursos de especializacion': '',
#   'Colabora en Open Source': '',
#   'Programa por hobbie': '',
#   'Persona con discapacidad': '',
#   'Edad': '37',
#   'Identidad de genero': 'Varón Cis'}]

# %%
# hago la union de las dos listas de diccionarios

dict_cases_list_ALL = dict_cases_list_LATAM + dict_cases_list_ARG

print(len(dict_cases_list_ALL))
# Out:
# 6879

# %% [markdown]
# 2. Printear porcentaje de participación por región, ordenado de mayor a menor. Ej:
#
# ```
# - Ciudad Autónoma de Buenos Aires - 59.4%
# - Formosa - 0.04%
# ```

# %%
#genero una lista de regiones a partir de los datos ARG + LATAM
list_regiones = []

for case in dict_cases_list_ALL:
    region = case["Region"]
    if region not in list_regiones:
        list_regiones.append(region)

# %%
#genero un diccionario vacio con las regiones como keys
dict_regiones = {}

for region in list_regiones:
    dict_regiones[region] = 0

# %%
# dic con cantidad de respuestas por region 
for case in dict_cases_list_ALL:
    region = case["Region"]
    dict_regiones[region] += 1

# %%
#ordeno el diccionario de mayor a menor por cantidad de respuestas

sorted_keys=sorted(dict_regiones,key=dict_regiones.get,reverse=True)

sorted_dict_regiones ={}

for key in sorted_keys:
    sorted_dict_regiones[key] = dict_regiones[key]

# %%
#creo diccionario con la c
dict_participacion_regiones = {}
total_respuestas = sum(sorted_dict_regiones.values())

for region in sorted_dict_regiones:
    participacion = round(((sorted_dict_regiones[region]/total_respuestas)*100),2)
    participacion_str = str(participacion)+"%"
    dict_participacion_regiones[region] = participacion_str

print("El porcentaje de participacion por Region es el siguiente :")
dict_participacion_regiones
# Out:
# El porcentaje de participacion por Region es el siguiente :
# {'Ciudad Autónoma de Buenos Aires': '51.64%',
#  'Provincia de Buenos Aires': '10.09%',
#  'GBA': '9.19%',
#  'Córdoba': '7.79%',
#  'Santa Fe': '5.81%',
#  'Mendoza': '2.18%',
#  'Montevideo': '1.7%',
#  'Entre Ríos': '0.96%',
#  'Río Negro': '0.76%',
#  'Tucumán': '0.76%',
#  'Neuquén': '0.68%',
#  'Misiones': '0.61%',
#  'Santiago': '0.58%',
#  'Chaco': '0.57%',
#  'México DF': '0.48%',
#  'Lima': '0.45%',
#  'Salta': '0.42%',
#  'San Juan': '0.35%',
#  'Corrientes': '0.35%',
#  'Bogotá': '0.28%',
#  'Chubut': '0.28%',
#  'Jujuy': '0.28%',
#  'Medellín': '0.25%',
#  'Quito': '0.23%',
#  'La Rioja': '0.23%',
#  'San Luis': '0.17%',
#  'Tierra del Fuego': '0.17%',
#  'Santiago de Cali': '0.13%',
#  'Ciudad Guatemala': '0.12%',
#  'La Pampa': '0.12%',
#  'Santiago del Estero': '0.12%',
#  'Guadalajara': '0.1%',
#  'Guayaquil': '0.09%',
#  'Asunción': '0.09%',
#  '': '0.09%',
#  'Santa Cruz de la Sierra': '0.07%',
#  'Santa Cruz': '0.07%',
#  'Caracas': '0.07%',
#  'Querétaro': '0.06%',
#  'Cochabamba': '0.04%',
#  'Valparaíso': '0.04%',
#  'Tunja': '0.04%',
#  'Manizales': '0.04%',
#  'San José': '0.04%',
#  'Loja': '0.04%',
#  'Monterrey': '0.04%',
#  'Veracruz': '0.04%',
#  'Puebla de Zaragoza': '0.04%',
#  'Valencia': '0.04%',
#  'Catamarca': '0.04%',
#  'La Paz': '0.03%',
#  'Pereira': '0.03%',
#  'Heredia': '0.03%',
#  'Cuenca': '0.03%',
#  'Pachuca': '0.03%',
#  'Oaxaca de Juárez': '0.03%',
#  'Villahermosa': '0.03%',
#  'Mérida': '0.03%',
#  'Morelia': '0.03%',
#  'Culiacán': '0.03%',
#  'Zapopan': '0.03%',
#  'Managua': '0.03%',
#  'Arequipa': '0.03%',
#  'Maldonado': '0.03%',
#  'Salto': '0.03%',
#  'Barquisimeto': '0.03%',
#  'San Cristóbal': '0.03%',
#  'Maipo': '0.01%',
#  'Biobío': '0.01%',
#  'Cachapoal': '0.01%',
#  'Talca': '0.01%',
#  'Valdivia': '0.01%',
#  'Cúcuta': '0.01%',
#  'Ibagué': '0.01%',
#  'Cartagena de Indias': '0.01%',
#  'Bucaramanga': '0.01%',
#  'Neiva': '0.01%',
#  'Montería': '0.01%',
#  'Arauca': '0.01%',
#  'Purral': '0.01%',
#  'Provincia de Ciudad de La Habana': '0.01%',
#  'Sancti Spíritus': '0.01%',
#  'Salinas': '0.01%',
#  'Ambato': '0.01%',
#  'Riobamba': '0.01%',
#  'Santa Tecla': '0.01%',
#  'San Salvador': '0.01%',
#  'Antigua Guatemala': '0.01%',
#  'San Pedro Sula': '0.01%',
#  'Cuernavaca': '0.01%',
#  'Saltillo': '0.01%',
#  'Chihuahua': '0.01%',
#  'Ecatepec': '0.01%',
#  'Victoria de Durango': '0.01%',
#  'Tijuana': '0.01%',
#  'Cancún': '0.01%',
#  'Ciudad Nezahualcóyotl': '0.01%',
#  'Chinandega': '0.01%',
#  'Ciudad de Panamá': '0.01%',
#  'San Lorenzo': '0.01%',
#  'Encarnación': '0.01%',
#  'Trujillo': '0.01%',
#  'Puno': '0.01%',
#  'Santo Domingo': '0.01%',
#  'Trinidad': '0.01%',
#  'Florida': '0.01%',
#  'Barcelona': '0.01%',
#  'Para analizar los resultados podés bajar el .csv (Archivo > Descargar como)': '0.01%',
#  'Recordá calificar a la empresa donde estás trabajando en www.openqube.io': '0.01%',
#  'Usá el código ENCUESTA en la tienda de sysarmy y llevate un 10% de descuento!': '0.01%',
#  'Dónde estás trabajando': '0.01%',
#  'Formosa': '0.01%'}

# %% [markdown]
# 3. Printear porcentaje de participación por tipo de rol, ordenado de mayor a menor. Ej:
# `- Developer - 39.11 %`

# %%
list_roles = []
dict_roles = {}
sorted_dict_roles ={}
dict_participacion_roles = {}

#genero una lista de roles a partir de los datos ARG + LATAM
for case in dict_cases_list_ALL:
    rol = case['Tipo de rol']
    if rol not in list_roles:
        list_roles.append(rol)
        
for rol in list_roles:
#     if "software engineer" in rol:
#        rol = "Software Engineer"
    dict_roles[rol] = 0

# %%
# dic con cantidad de respuestas por rol
for case in dict_cases_list_ALL:
    rol = case['Tipo de rol']
    dict_roles[rol] += 1
    sorted_keys=sorted(dict_roles,key=dict_roles.get,reverse=True)
    
for key in sorted_keys:
    sorted_dict_roles[key] = dict_roles[key]

total_respuestas = sum(sorted_dict_roles.values())
for rol in sorted_dict_roles:
    participacion = round(((sorted_dict_regiones[region]/total_respuestas)*100),2)
    participacion_str = str(participacion)+"%"
    dict_participacion_roles[rol] = participacion_str
    
# print("El porcentaje de participacion por Tipo de Rol es el siguiente :")
# dict_participacion_roles
dict_roles
# Out:
# {'sysadmin / devops / sre': 762,
#  'developer': 2795,
#  'architect': 153,
#  'networking': 106,
#  'business analyst': 116,
#  'technical leader': 423,
#  'vp / c-level': 38,
#  'consultant': 132,
#  'qa / tester': 295,
#  'scrum master': 45,
#  'alliances manager (indirect sales)': 1,
#  'data engineer': 121,
#  'project manager': 212,
#  'bi analyst / data analyst': 168,
#  'data quality': 1,
#  'analista': 3,
#  'infosec': 98,
#  'ux': 103,
#  'aprentice': 1,
#  'helpdesk': 180,
#  'docente': 5,
#  'product manager': 83,
#  'ingeniero infraestructuras de virtualizacion': 1,
#  'manager / director': 294,
#  'data scientist': 102,
#  'teacher': 1,
#  'profesor de teatro ': 1,
#  'ti': 1,
#  'mix entre sysadmin y developer pasando por dba': 1,
#  'dba': 49,
#  'chef': 1,
#  'designer': 44,
#  'artesanal': 1,
#  'technical support engineer': 1,
#  'technical writer': 11,
#  'sales / pre-sales': 29,
#  'salesforce admin/developer': 1,
#  'middleware': 12,
#  'storage / backup': 8,
#  'analista funcional de sistemas': 1,
#  'independiente ': 1,
#  'team leader': 5,
#  'soporte on site': 1,
#  'app analyst': 1,
#  'agile coach': 4,
#  'cajera': 1,
#  '': 9,
#  'trabajo de': 1,
#  'recruiter / hr': 85,
#  'technical business analyst': 1,
#  'administrador infraestructura': 1,
#  'help desk + backup + vmware + sys admin': 1,
#  'data visualization': 1,
#  'mainframe': 1,
#  'machine learning egineer': 1,
#  'exploit writer': 1,
#  'bi sr. manager': 1,
#  'operador': 1,
#  'support engineer': 2,
#  'people analytics': 2,
#  'soporte nivel 1,2 y 3': 1,
#  ' cloud architect': 1,
#  'finance': 12,
#  'engineering manager': 1,
#  'técnicamente soy qa pero hago trabajo de po ¿trainee?': 1,
#  'sre': 1,
#  'supervisor helpdek': 1,
#  'data architect': 2,
#  'asistencia técnica': 1,
#  'lead': 1,
#  'analista funcional': 12,
#  'soporte': 3,
#  'tech support ': 1,
#  'back office': 1,
#  'productor y vendedor': 2,
#  'jefe operacion ti': 1,
#  'auditoría': 1,
#  'cloud security': 2,
#  'nlp developer': 2,
#  'it infrastructure engineer': 1,
#  'data center': 1,
#  'soporte tecnico': 3,
#  'sdet': 2,
#  'software engineer ': 1,
#  'profesor': 2,
#  'information security': 1,
#  'sap basis': 1,
#  'seguridad informática ': 1,
#  'seguridad': 1,
#  'coordinador operaciones y soporte aplicativo': 1,
#  'application engineer': 1,
#  'becario doctoral ': 1,
#  'automation engineer': 1,
#  'software engineer': 4,
#  'analista tecnico': 1,
#  'frontend developer': 2,
#  'cybersecurity': 3,
#  'jefe de sistemas': 2,
#  'it auditor': 1,
#  'security architect': 1,
#  'implementacion de sistemas informatico de salud -sap -funcional': 1,
#  'gerente de sistemas': 1,
#  'soporte  técnico nivel 3 (infraestructura)': 1,
#  'seguridad informatica': 1,
#  'comunicación / redes sociales': 1,
#  'adm de infra': 1,
#  'developer, devops': 1,
#  'analista sap basis': 1,
#  'soporte tecnico sql': 1,
#  'qa automation ': 1,
#  'functional analyst': 4,
#  'av technical support': 1,
#  'sales executive': 1,
#  'etl developer': 1,
#  'security researcher': 1,
#  'gerente de atracción de ti y comercial': 1,
#  'cybersecurity ': 1,
#  'product owner': 6,
#  'delivery manager': 1,
#  'varios': 1,
#  'integration ': 1,
#  'problem manager': 1,
#  'technical analyst': 2,
#  'soporte it lab nivel 1, 2, 3 ': 1,
#  'director of devops and it': 1,
#  'proyect leader / developer / toolsmith': 1,
#  'technical owner': 1,
#  'service designer': 2,
#  'datasteward': 1,
#  'seguridad informática - accesos': 1,
#  'project engineering': 2,
#  'ipm': 1,
#  'esp. telecomunicaciones': 1,
#  'qa - automation engineer': 1,
#  'ad tech': 1,
#  'trainee etl': 1,
#  'data governance specialist': 1,
#  'jefe de canales digitales': 1,
#  'ingeniero en seguridad informatica': 1,
#  'incident&risk leader': 1,
#  'machine learning engineer': 1,
#  'developer/devops': 1,
#  'ux user research': 1,
#  'ux leader': 1,
#  'it operations analyst': 1,
#  'customer success manager': 1,
#  'marketing': 1,
#  'auditor': 2,
#  'qa automation': 2,
#  'analista mainframe': 1,
#  'application dba': 1,
#  'network analyst security': 1,
#  'uxui': 1,
#  'tech lead / arquitecto': 1,
#  'consultor senior - especialista en ciberseguridad': 1,
#  'qa lead': 2,
#  'service delivery manager, application support, itgc': 1,
#  'administrador de windows server - cloud': 1,
#  'analista contable ': 1,
#  'servicio técnico ': 1,
#  'functional analyst jr': 1,
#  'devops': 4,
#  'operation lead': 1,
#  'cloud admin': 2,
#  'technical support': 1,
#  'analista it': 1,
#  'integration developer': 1,
#  'profesor de tecnología de la información': 1,
#  'appdynamics engineer': 1,
#  'ui': 2,
#  'research': 1,
#  'functional': 1,
#  'technical account manager': 1,
#  'analista de sistema': 1,
#  'ingeniero de laboratorio': 1,
#  'gerente': 1,
#  'atlassian specialist': 1,
#  'rpa & etl developer': 1,
#  'mezcla de sysadmin, networking, dba... de todo un poco': 1,
#  'full stack y bi': 1,
#  'soporte it': 2,
#  'nlp analyst': 1,
#  'analista de metodología': 1,
#  'computational linguist junior': 1,
#  'analista npl': 1,
#  'consultor de implementación': 1,
#  'noc': 1,
#  'analista de sistemas': 1,
#  'trafficker': 1,
#  'calidad': 1,
#  'coordinador': 3,
#  'rrhh': 1,
#  'creative copywriter': 1,
#  'pipeline technical artist': 1,
#  'desarrollador plsql + desarrollador web + soporte-analista funcional': 1,
#  'analista seguridad informatica': 1,
#  'sr staff engineer': 1,
#  'tech manager': 1,
#  'analista funcional sr': 1,
#  'jefe de it': 1,
#  'ingeniero de soporte': 1,
#  'gerente de atracción de talentos y comercial': 1,
#  'product designer': 1,
#  'rpa': 3,
#  'senior product owner': 1,
#  'product support': 1,
#  'cloud engineer': 2,
#  'ingeniero en informatica': 1,
#  'responsable de marketing': 1,
#  'data modeling engineer': 1,
#  'cto': 1,
#  'analisis funcional': 1,
#  'media comunnications': 1,
#  'analyst': 1,
#  'ui ': 1,
#  'jefe de soporte y operaciones': 1,
#  'soy el dpto de sistemas en una escuela de 80 pc y 400 por wifi..hago todo': 1,
#  'cyber security': 1,
#  'analytics engineer': 1,
#  'conversational designer': 1,
#  'administrativo': 2,
#  'access managment sr': 1,
#  'sistemas': 1,
#  'productora de eventos': 1,
#  'it specialist': 1,
#  'product analyst': 1,
#  'soporte técnico': 2,
#  'change manager': 2,
#  'support senior': 1,
#  'soporte transaccional': 1,
#  'suport l2': 1,
#  'erp developer': 1,
#  'rpa developer': 2,
#  'test automation engineer': 1,
#  'field operations / telecommunications': 1,
#  'research engineer': 1,
#  'responsable de área de sistemas ': 1,
#  'soporte nivel 2': 1,
#  'encargado área de sistemas': 1,
#  'atlassian consultant': 1,
#  'business analyst y scrum master': 1,
#  'noc ': 1,
#  'full stack developer': 1,
#  'supportengineer': 1,
#  'docencia': 1,
#  'cloudengineer/dev/devops': 1,
#  'artist': 1,
#  'product lead': 1,
#  'team lead': 1,
#  'project manager, product manager, developer, sre': 1,
#  'tecnico telecomunicaciones': 1,
#  'laboratorio universitario': 1,
#  'administrativo ': 1,
#  'site support': 1,
#  'wordpress': 1,
#  'cloud': 1,
#  'it services': 1,
#  'lead data engineer': 1,
#  'project leader': 1,
#  'administrativa': 1,
#  'cro': 1,
#  'trainee': 1,
#  'security engineer': 1,
#  'operador noc': 2,
#  'tecnico de calle': 1,
#  'redactor y editor, diseño, contenidos': 1,
#  'product security': 1,
#  'on site support': 1,
#  'sap basis administrator': 1,
#  'crm developer': 1,
#  'integrator': 1,
#  'administrativa ': 1,
#  'soporte tecnico de infraestructura': 1,
#  'administrativo de deposito': 1,
#  'postproducer': 1,
#  'devops, desarrollo, diseño, instalo arquitectura, monitoreo, etc': 1,
#  'systems integration analyst': 1,
#  'people care': 1,
#  'docente universitario': 1,
#  'helpdesl / tecnico en reparacion de pc, notebooks e impresoras / tecnico instalador de hfc y ftth': 1,
#  'security analist': 1,
#  'de todo un poco': 1,
#  'fullstack': 1,
#  'especialista en yacimiento digital': 1,
#  'mezcla entre helpdesk y admin base de datos': 1,
#  'productivity & collaboration': 1,
#  'dba / developer': 1,
#  'ayudante en cursos de programación': 1,
#  'administrador de sistema erp': 1,
#  'growth engineer ': 1,
#  'programador': 1,
#  'tecnology': 1,
#  'jefe división informática': 1,
#  'subject matter expert': 1,
#  'bi engineer': 1,
#  'de todo': 1,
#  'analista funcional ': 1,
#  'digital marketing': 1,
#  'analista funcional y coordinadora de grupo de mantenimiento ': 1,
#  'ti-infraestructura': 1,
#  'security research': 1,
#  'support': 1,
#  'responsable it': 1,
#  'profesor de informática': 1,
#  'frontend chapter lead': 1,
#  'software ingeniero': 1,
#  'tutor': 1,
#  'technical support (not help desk)': 1,
#  'principal se': 1,
#  'bi developer': 1,
#  'architecture engineering ': 1,
#  'pmo manager': 1,
#  'instructor': 1,
#  'chapter lead': 1,
#  'programador de automatas': 1,
#  'responsable de infraestructura': 1,
#  'deposito': 1,
#  'ui - frontend': 1,
#  'cio': 1,
#  'cashier': 1,
#  'operations lead': 1,
#  'freelance': 1,
#  'application support': 1,
#  'dba+frontend': 1,
#  'education': 1,
#  'it support': 1,
#  'business analyst, qa / tester, project manager,product manager': 1,
#  'referente de area ': 1,
#  'desarrollos de modelos fisicos en c, c++ o python, para ser integrados en un software de simulacion de vuelo': 1,
#  'administracion': 1,
#  'redacción': 1,
#  'tecnico': 1,
#  'administración': 1,
#  'redactor creativo': 1,
#  'telecomunicaciones ': 1,
#  'desarrollador etl': 1,
#  'analista implementador': 1,
#  'jefe de área de sistemas': 1,
#  'estructurado': 1,
#  'soporte de campo': 1,
#  'implementador de sistemas': 2,
#  'auditoria': 1,
#  'ingeniero electrónico': 1,
#  'implementador': 1,
#  'sysadmin / storage / backup / networking': 1,
#  'community manager en it': 1,
#  'ti generalista': 1,
#  'atención al cliente en naranja x': 1}

# %% [markdown]
# 4. Printear porcentaje de respuesta para las preguntas:
# * ¿Contribuís a proyectos Open Source?
# * ¿Programás por hobbie?

# %%
#genero una lista de respuestas "si" , "no" , "sin respuesta" a partir de los datos ARG + LATAM
list_respuestas = []

for case in dict_cases_list_ALL:
    respuesta = case['Colabora en Open Source']
    if respuesta not in list_respuestas:
        list_respuestas.append(respuesta)
        
list_respuestas
# Out:
# ['No', '', 'Sí']

# %%
for index, item in enumerate(list_respuestas):
        if item == "":
            list_respuestas[index] = "Sin respuesta"
            
list_respuestas
# Out:
# ['No', 'Sin respuesta', 'Sí']

# %%
dict_respuestas =  {}
for respuesta in list_respuestas:
    dict_respuestas[respuesta] = 0

dict_respuestas
# Out:
# {'No': 0, 'Sin respuesta': 0, 'Sí': 0}

# %%
# dic con cantidad de respuestas si , no , sin responder
for case in dict_cases_list_ALL:
    respuesta = case['Colabora en Open Source']
    dict_respuestas[respuesta] += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-e03936993774> in <module>
#       2 for case in dict_cases_list_ALL:
#       3     respuesta = case['Colabora en Open Source']
# ----> 4     dict_respuestas[respuesta] += 1
#
# KeyError: ''

# %% [markdown]
# 5. Printear porcentaje por seniority según años de experiencia, el mapeo es:
# ```
# Junior: de 0 hasta 2 años.
# Semi-Senior: de 2 años inclusive hasta 5 años.
# Senior: desde 5 años inclusive.
# ```

# %% [markdown]
# 6. Printear porcentaje de personas encuestadas por años en la compañía actual y por años en el puesto actual.

# %% [markdown]
# 7. Printear porcentajes de nivel de educación formal y estado, es decir: % educación secundaria, terciaria, universitaria, postgrado, doctorado, postdoctorado, completo, incompleto y en curso para cada uno.

# %% [markdown]
# 8. Formatear las carreras universitarias:
# - Nombres capitalizados
# - Reemplazar vocales con tilde por vocales sin tilde.
# - Reemplazar `ñ` por `n`
# - *lic*, *lic.* por Licenciatura
# - *tec*, *tec.* por Tecnucatura
# * *cs, *cs.* por Ciencias
# * *ed, ed.* por Educación
# * Transformaciones que se consideren necesarias
#
# Printear porcentaje según carrera

# %% [markdown]
# 9. Printear porcentaje de respuesta a las preguntas:
# - ¿Realizaste cursos de especialización?
# - Si realizaste, ¿Quién pagó por los cursos de especialización?

# %% [markdown]
# 10. Printear porcentaje por identidad de género y personas con discapacidad

# %% [markdown]
# 11. Salarios: calcular la mediana salarial para cada una de las siguientes categorías:
# - Salario según región
# - Salario por rol
# - Salario por experiencia
# - Salario por nivel de formación
# - Salario por carrera
# - Salario por tecnología
# - Salario por lenguaje de programación
# - Salario por género

# %% [markdown]
# 12. Printear porcentaje y salario según tipos de contrato .
